# %% [markdown]
# # Z Distribution <hr style = "border:2.5px solid #ff0000ff"></hr>

# %% [markdown]
# <b> Shedrick Lim </b>
# <br>Comptech Student T09

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv(r"C:\Users\ASUS\Desktop\Lim\Dataset\transformer-voltage.csv")

df
# Out:
#     Sample  Voltage
# 0        1    117.0
# 1        2    118.3
# 2        3    119.5
# 3        4    119.5
# 4        5    119.6
# 5        6    119.6
# 6        7    119.7
# 7        8    119.7
# 8        9    119.7
# 9       10    119.8
# 10      11    119.8
# 11      12    119.8
# 12      13    120.0
# 13      14    120.4
# 14      15    120.5
# 15      16    120.5
# 16      17    120.5
# 17      18    120.1
# 18      19    120.1
# 19      20    120.1
# 20      21    120.2
# 21      22    120.2
# 22      23    120.2
# 23      24    121.0
# 24      25    121.1
# 25      26    121.6
# 26      27    121.7
# 27      28    122.2
# 28      29    122.5
# 29      30    123.8

# %%
df.describe()
# Out:
#           Sample     Voltage
# count  30.000000   30.000000
# mean   15.500000  120.290000
# std     8.803408    1.243285
# min     1.000000  117.000000
# 25%     8.250000  119.700000
# 50%    15.500000  120.100000
# 75%    22.750000  120.500000
# max    30.000000  123.800000

# %%
df.info
# Out:
# <bound method DataFrame.info of     Sample  Voltage
# 0        1    117.0
# 1        2    118.3
# 2        3    119.5
# 3        4    119.5
# 4        5    119.6
# 5        6    119.6
# 6        7    119.7
# 7        8    119.7
# 8        9    119.7
# 9       10    119.8
# 10      11    119.8
# 11      12    119.8
# 12      13    120.0
# 13      14    120.4
# 14      15    120.5
# 15      16    120.5
# 16      17    120.5
# 17      18    120.1
# 18      19    120.1
# 19      20    120.1
# 20      21    120.2
# 21      22    120.2
# 22      23    120.2
# 23      24    121.0
# 24      25    121.1
# 25      26    121.6
# 26      27    121.7
# 27      28    122.2
# 28      29    122.5
# 29      30    123.8>

# %%
alpha = 0.05
z_critical = stats.norm.ppf(1 - alpha/2)
z_critical
# Out:
# np.float64(1.959963984540054)

# %%
pop_std = 5

ci_lower, ci_upper = stats.norm.interval(
    confidence = 0.95, 
    loc=df['Voltage'].mean(), 
    scale=pop_std/np.sqrt(df['Voltage'].count())
)

df['Voltage'].mean(), ci_lower, ci_upper

print(f"CI = [{ci_lower:.2f}, {ci_upper:.2f}]")
# Out:
# CI = [118.50, 122.08]

# %%
mean = df['Voltage'].mean()
std = df['Voltage'].std(ddof=1)

x_min = df['Voltage'].min()
x_max = df['Voltage'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, mean, std)



plt.plot(x,p,
         color = 'Blue',
         linewidth = 2)

plt.hist(df['Voltage'],
         bins=5,
         density= True,
         alpha=0.8,
         color = 'Orange',
         edgecolor = 'Black')


plt.title('Voltage Distribution of Transformer',
         font = 'Palatino Linotype',
         fontsize= 12)
plt.xlabel('Voltage (V)')
plt.ylabel('Density')
plt.show()
