# %% [markdown]
# # T-Distribution <hr style = "border:2.5px solid #ff0000ff"></hr>

# %% [markdown]
# <b> Shedrick Lim </b>
# <br>Comptech Student T09

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv(r"C:\Users\ASUS\Desktop\Lim\Dataset\transformer-voltage-10-sample.csv")

df
# Out:
#    Sample  Voltage
# 0       1    118.3
# 1       2    119.2
# 2       3    119.7
# 3       4    119.5
# 4       5    120.0
# 5       6    120.1
# 6       7    120.2
# 7       8    120.8
# 8       9    121.5
# 9      10    121.8

# %%
df.describe()
# Out:
#          Sample     Voltage
# count  10.00000   10.000000
# mean    5.50000  120.110000
# std     3.02765    1.050344
# min     1.00000  118.300000
# 25%     3.25000  119.550000
# 50%     5.50000  120.050000
# 75%     7.75000  120.650000
# max    10.00000  121.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Sample   10 non-null     int64
#  1   Voltage  10 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 292.0 bytes

# %%
alpha = 0.05
n = df['Voltage'].count()

t_critical = stats.norm.ppf(1 - alpha/2,n-1)
t_critical
# Out:
# np.float64(10.959963984540053)

# %%
n = df['Voltage'].count()
mean = df['Voltage'].mean()
std = df['Voltage'].std(ddof = 1)
 
ci_lower, ci_upper = stats.t.interval(
    confidence = 0.95, 
    df = n-1,
    loc = mean,
    scale=std/np.sqrt(n)
)



print(f"CI = [{ci_lower:.2f}, {ci_upper:.2f}]")
# Out:
# CI = [119.36, 120.86]

# %%
mean = df['Voltage'].mean()
std = df['Voltage'].std(ddof=1)

x_min = df['Voltage'].min()
x_max = df['Voltage'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, mean, std)

plt.hist(df['Voltage'],
         bins=5,
         density= True,
         alpha=0.8,
         color = 'Orange',
         edgecolor = 'Black')


plt.plot(x,p,
         color = 'Blue',
         linewidth = 2)



plt.axvline(x = ci_lower,
           color = 'blue',
           linestyle = "--"
)

plt.axvline(x = ci_upper,
           color = 'blue',
           linestyle = "--"
)
plt.title('Voltage Distribution of Transformer',
         font = 'Palatino Linotype',
         fontsize= 12)
plt.xlabel('Voltage (V)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ## Shoe Inventory <hr style = "border:2.5px solid #ff0000ff"></hr>

# %%
df = pd.read_csv(r"C:\Users\ASUS\Desktop\Lim\Dataset\shoe-inventory.csv")

df
# Out:
#     Size  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 0    6.0    4    1    3    1    3    3    3    4    3    7    3    0
# 1    6.5    3    2    0    1    0    0    1    7    2    1    2    1
# 2    7.0    0    0    1    0    6    4    4    2    3    0    0    0
# 3    7.5    3    2    3    1    7    0    7    3    4    6    1    1
# 4    8.0    7    9    7    3   12    2    9    4    7    5    2    6
# 5    8.5   12   12    8    8   15    9   17   17    6    9   10    6
# 6    9.0   17   13   13   11   21   22   25   30   26   25   13   10
# 7    9.5   19   25   27   24   26   33   25   47   31   44   37   26
# 8   10.0   17   26   26   19   16   31   25   24   23   31   15   20
# 9   10.5   13   16   22   14   28   19   18   15   19   21   16   10
# 10  11.0    5   16   13   10   10   11   15    8    9    7    6    7
# 11  11.5    4    3    6    3    3    5    6    4    5   12   13    5
# 12  12.0    3    0    0    4    4    4    3   12    4    9    2    1
# ...

# %%
df.shape
# Out:
# (17, 13)

# %%
mean_size_6 = df.iloc[0,1:13].mean()
mean_size_6
# Out:
# np.float64(2.9166666666666665)

# %%
std_size_6 = df.iloc[0,1:13].std()
std_size_6
# Out:
# 1.781640374554423

# %%
n = df.shape[1]-1

lower_6, upper_6 = stats.t.interval(
    confidence= 0.95,
    df = n-1,
    loc = mean_size_6,
    scale = std_size_6/np.sqrt(n)
)

print(f"CI_6:[{lower_6:.2f},{upper_6:.2f}]")
# Out:
# CI_6:[1.78,4.05]

# %%
mean = df.iloc[0:17,1:13].mean(axis=1)
std = df.iloc[0:17,1:13].std(axis=1)

df['ci_lower'], df['ci_upper'] = stats.t.interval(
    confidence= 0.95,
    df = n-1,
    loc = mean,
    scale = std/np.sqrt(n)
)

df
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2323: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# c:\Users\ASUS\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2324: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
#     Size  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  \
# 0    6.0    4    1    3    1    3    3    3    4    3    7    3    0
# 1    6.5    3    2    0    1    0    0    1    7    2    1    2    1
# 2    7.0    0    0    1    0    6    4    4    2    3    0    0    0
# 3    7.5    3    2    3    1    7    0    7    3    4    6    1    1
# 4    8.0    7    9    7    3   12    2    9    4    7    5    2    6
# 5    8.5   12   12    8    8   15    9   17   17    6    9   10    6
# 6    9.0   17   13   13   11   21   22   25   30   26   25   13   10
# 7    9.5   19   25   27   24   26   33   25   47   31   44   37   26
# ...

# %%
df['ci_lower'] = df['ci_lower'].fillna(0)
df['ci_upper'] = df['ci_upper'].fillna(0)

df
# Out:
#     Size  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  \
# 0    6.0    4    1    3    1    3    3    3    4    3    7    3    0
# 1    6.5    3    2    0    1    0    0    1    7    2    1    2    1
# 2    7.0    0    0    1    0    6    4    4    2    3    0    0    0
# 3    7.5    3    2    3    1    7    0    7    3    4    6    1    1
# 4    8.0    7    9    7    3   12    2    9    4    7    5    2    6
# 5    8.5   12   12    8    8   15    9   17   17    6    9   10    6
# 6    9.0   17   13   13   11   21   22   25   30   26   25   13   10
# 7    9.5   19   25   27   24   26   33   25   47   31   44   37   26
# 8   10.0   17   26   26   19   16   31   25   24   23   31   15   20
# 9   10.5   13   16   22   14   28   19   18   15   19   21   16   10
# 10  11.0    5   16   13   10   10   11   15    8    9    7    6    7
# 11  11.5    4    3    6    3    3    5    6    4    5   12   13    5
# 12  12.0    3    0    0    4    4    4    3   12    4    9    2    1
# ...

# %%
df['ci_lower'] = df['ci_lower'].astype(int).round()
df['ci_upper'] = df['ci_upper'].astype(int).round()

df
# Out:
#     Size  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  \
# 0    6.0    4    1    3    1    3    3    3    4    3    7    3    0
# 1    6.5    3    2    0    1    0    0    1    7    2    1    2    1
# 2    7.0    0    0    1    0    6    4    4    2    3    0    0    0
# 3    7.5    3    2    3    1    7    0    7    3    4    6    1    1
# 4    8.0    7    9    7    3   12    2    9    4    7    5    2    6
# 5    8.5   12   12    8    8   15    9   17   17    6    9   10    6
# 6    9.0   17   13   13   11   21   22   25   30   26   25   13   10
# 7    9.5   19   25   27   24   26   33   25   47   31   44   37   26
# 8   10.0   17   26   26   19   16   31   25   24   23   31   15   20
# 9   10.5   13   16   22   14   28   19   18   15   19   21   16   10
# 10  11.0    5   16   13   10   10   11   15    8    9    7    6    7
# 11  11.5    4    3    6    3    3    5    6    4    5   12   13    5
# 12  12.0    3    0    0    4    4    4    3   12    4    9    2    1
# ...

# %%
df[['Size','ci_upper']]
# Out:
#     Size  ci_upper
# 0    6.0         4
# 1    6.5         2
# 2    7.0         3
# 3    7.5         4
# 4    8.0         8
# 5    8.5        13
# 6    9.0        23
# 7    9.5        35
# 8   10.0        26
# 9   10.5        20
# 10  11.0        11
# 11  11.5         7
# 12  12.0         6
# 13  13.0         2
# 14  14.0         3
# 15  15.0         1
# 16  16.0         0

# %%
final = df[['Size','ci_upper']]

final
# Out:
#     Size  ci_upper
# 0    6.0         4
# 1    6.5         2
# 2    7.0         3
# 3    7.5         4
# 4    8.0         8
# 5    8.5        13
# 6    9.0        23
# 7    9.5        35
# 8   10.0        26
# 9   10.5        20
# 10  11.0        11
# 11  11.5         7
# 12  12.0         6
# 13  13.0         2
# 14  14.0         3
# 15  15.0         1
# 16  16.0         0
